# %% [markdown]
# ## Linear Regression Deployment

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv('placement.csv')

# %%
df=pd.DataFrame(df)

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.tail()
# Out:
#      cgpa  package
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33

# %%
df.size
# Out:
# 400

# %%
df.shape
# Out:
# (200, 2)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %% [markdown]
# ## Classify the Independent(X) and Dependent Variable(y)

# %%
X=df[['cgpa']]

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['cgpa', 'package'], dtype='object')

# %%
y=df[['package']]

# %%
y
# Out:
#      package
# 0       3.26
# 1       1.98
# 2       3.25
# 3       3.67
# 4       3.57
# ..       ...
# 195     2.46
# 196     2.57
# 197     3.24
# 198     3.96
# 199     2.33
#
# [200 rows x 1 columns]

# %% [markdown]
# ## Data Visualization

# %%
plt.scatter(X,y, marker ='*')
plt.title('cgpa V/s placement')
plt.xlabel('cgpa')
plt.ylabel('placement')
plt.show()

# %% [markdown]
# ## Model Selection

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y, test_size=0.1, shuffle =False)

# %%
X_train.head()
# Out:
#    cgpa
# 0  6.89
# 1  5.12
# 2  7.82
# 3  7.42
# 4  6.94

# %%
y_train.shape
# Out:
# (180, 1)

# %%
y_test.head()
# Out:
#      package
# 180     2.72
# 181     3.89
# 182     2.08
# 183     2.72
# 184     3.14

# %%
from  sklearn.linear_model import LinearRegression

# %%
slr= LinearRegression()

# %%
X_train.shape
# Out:
# (180, 1)

# %%
y_train.shape
# Out:
# (180, 1)

# %%
model=slr.fit(X_train, y_train)

# %%
y_predict =model.predict(X_test)

# %%
y_predict
# Out:
# array([[2.53296473],
#        [3.6904854 ],
#        [2.35620049],
#        [3.15449061],
#        [3.49661495],
#        [2.6013896 ],
#        [3.47380666],
#        [2.57287924],
#        [3.19440511],
#        [3.62776261],
#        [2.53296473],
#        [3.15449061],
#        [3.70759162],
#        [1.60922902],
#        [3.50231702],
#        [2.95491808],
#        [2.36190256],
#        [3.1145761 ],
#        [3.35406314],
#        [2.55007095]])

# %% [markdown]
# ## Best Fit Line

# %%
plt.scatter(X_train, y_train, color = 'r')
plt.plot(X_test, y_predict, color ='b')
plt.title('cgpa V/s placement')
plt.xlabel('cgpa')
plt.ylabel('placement')
plt.show()

# %%
model.coef_
# Out:
# array([[0.57020723]])

# %%
model.intercept_
# Out:
# array([-0.99661801])

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn import metrics

# %%
R_squared = r2_score(y_test, y_predict)

# %%
R_squared
# Out:
# 0.7437616703968744

# %%
model.score(X_train,y_train)
# Out:
# 0.7782496220450584

# %%
actual =y_test
calculated = y_predict

error = mae(actual, calculated)
print("Mean absolute error : " + str(error))
# Out:
# Mean absolute error : 0.2696824469109914

# %%
mean_squared_error(y_predict, y_test)
# Out:
# 0.10044612985983163
